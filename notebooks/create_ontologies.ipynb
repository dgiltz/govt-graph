# %% [markdown]
# This is just a hacky workaround until I can figure out proper autocomplete / module suggestion using pdm and vs code

# %%
from rdflib import Graph, Namespace
from rdflib.namespace import RDF, FOAF, OWL, XSD

# %% [markdown]
# # Legislative Branch
# Covers the legislative branch of the US gov't, including congresspeople, senators, their districts and legislature (bills, amendements, etc.)
#
# ## Core Competency Questions
#
# ### Entirely Covered by This
# - Who is the congressperson for *__{district}__* in *__{state}__*?
# - Who are the senators for *__{state}__*?
# - When is *__{legislator}__* up for election?
# - What committees does *__{legislator}__* serve on?
# - How many terms has *__{legislator}__* served?
# - What bills has *__{legislator}__* sponsored in *__{timeframe}__*?
# - Which *__{legislators}__* has *__{legislator}__* cosponsored a bill with in *__{timeframe}__*?
# - What is the intent of *__{bill}__*?
# - How does *__{amendment}__* change *__{bill}__*?
# - What is *__{legislator}__*'s voting record in the last *__{number}__* house resolutions?
# - What is the impact of *__{bill}__* on *__{program}__*?
# - What is the purview of *__{committee}__*?
# - Who are the members of *__{committee}__*?
# - Who are the ranking members of *__{committee}__*?
# - When was *__{bill}__* introduced?
# - What are the current amendments to *__{bill}__*?
# - What is the voting record for *__{bill}__*?
# - What previously enacted legislation does *__{bill}__* effect?
#
# ### This + Another Ontology
# - What topics/issues relate to *__{bill}__*?
# - How does *__{bill}__* address *__{topic or issue}__*?
# - Does *__{bill}__* address any promises *__{legislator}__* made to their constituents?
# - Does *__{bill}__* run counter to any promises *__{legislator}__* made to their constituents?
# - What promises has *__{legislator}__* made on *__{topic or issue}__*?
# - How does *__{bill}__* effect funding for *__{program of agency}__*?

# %%
graph = Graph()
legislative = Namespace("http://govt-graph.com/us/legislative")
